# %%
import os, sys, email
import json
import time
import datetime
import ast

import numpy as np
import pandas as pd

import community
import networkx as nx

from tqdm import tqdm

# %%
TOPIC_KEYWORD = 'email'
POSTS_THRESHOLD = 0 # involve all people
LINKS_THRESHOLD = 20
DEGREE_THRESHOLD = 5
HIGH_CONTRIBUTION_THRESHOLD = 60

# DB_CONNECT_STRING = 'mysql+pymysql://root:Initial0@10.58.78.253:3306/nexus?charset=utf8mb4'

# engine = create_engine(DB_CONNECT_STRING, max_overflow=5)
FILEPATH = './output/external-people-email.json'

# %%
class CommunityStructure:
    def __init__(self, keyword, filepath):
        self.nodes = []
        self.links = []
        self.graph = nx.Graph(name='community-network')
        self.partition = []
        self.community_size = dict()
        self.keyword = keyword
#         self.timestamp = timestamp
#         self.nonorg = nonorg
        self.source_file_path = filepath
        

    def set_nodes_with_links(self):
        if not os.path.exists(self.source_file_path):
            return

        with open(self.source_file_path) as json_file:
            ds = json.load(json_file)
            self.nodes = ds['nodes']
            self.links = ds['links']

        print('nodes:', len(self.nodes), 'links:', len(self.links))

    def community_analysis(self):
        if len(self.nodes) == 0 or len(self.links) == 0:
            return

        # g = nx.Graph(name='community-network')
        for item in self.links:
            self.graph.add_edge(item['source'], item['target'])

        self.partition = community.best_partition(self.graph)

        print('partition:', len(self.partition))

        if len(self.partition) > 0:
            for k, v in self.partition.items():
                # v -> ###### string
                str_v = str(v).zfill(6)
                if str_v in self.community_size:
                    self.community_size[str_v] += 1
                else:
                    self.community_size[str_v] = 1

        print('community:', len(self.community_size))

    def set_node_community_attr(self):
        if len(self.nodes) == 0 or len(self.links) == 0 or len(self.partition) == 0:
            return

        for node in self.nodes:
            if node['name'] in self.partition:
                node['community'] = str(self.partition[node['name']]).zfill(6)
                node['community_size'] = self.community_size[node['community']]

    def export_dataset(self):
        result = {"nodes": self.nodes, "links": self.links}
        with open(self.source_file_path, 'w', encoding='utf-8') as json_file:
            json.dump(result, json_file, ensure_ascii=False)

        return result

# %%
ds = CommunityStructure(TOPIC_KEYWORD, FILEPATH)

ds.set_nodes_with_links()
ds.community_analysis()
ds.set_node_community_attr()
final_result = ds.export_dataset()
# Out:
# nodes: 150 links: 2003
# partition: 140
# community: 7

# %%
final_result
# Out:
# {'nodes': [{'name': 'dean-c',
#    'username': 'dean-c',
#    'displayname': 'dean-c',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 59.54,
#    'posts': 2429,
#    'comments': 12914,
#    'degree': 15.11,
#    'betweenness': 6.22,
#    'closeness': 67.8,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'kitchen-l',
#    'username': 'kitchen-l',
#    'displayname': 'kitchen-l',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 39.75,
#    'posts': 5546,
#    'comments': 23657,
#    'degree': 52.37,
#    'betweenness': 4.24,
#    'closeness': 83.16,
#    'networktype': 'Connectors',
#    'category': 'Connectors',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'williams-j',
#    'username': 'williams-j',
#    'displayname': 'williams-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 81.95,
#    'posts': 1213,
#    'comments': 7893,
#    'degree': 20.14,
#    'betweenness': 0.75,
#    'closeness': 68.76,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'harris-s',
#    'username': 'harris-s',
#    'displayname': 'harris-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 92.33,
#    'posts': 548,
#    'comments': 3868,
#    'degree': 18.13,
#    'betweenness': 0.11,
#    'closeness': 59.69,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'jones-t',
#    'username': 'jones-t',
#    'displayname': 'jones-t',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 46.11,
#    'posts': 19950,
#    'comments': 91840,
#    'degree': 31.22,
#    'betweenness': 1.83,
#    'closeness': 74.56,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'corman-s',
#    'username': 'corman-s',
#    'displayname': 'corman-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 46.26,
#    'posts': 2025,
#    'comments': 9338,
#    'degree': 24.17,
#    'betweenness': 1.01,
#    'closeness': 66.87,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'storey-g',
#    'username': 'storey-g',
#    'displayname': 'storey-g',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 41.11,
#    'posts': 1027,
#    'comments': 4455,
#    'degree': 21.15,
#    'betweenness': 0.47,
#    'closeness': 69.01,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'pereira-s',
#    'username': 'pereira-s',
#    'displayname': 'pereira-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 41.84,
#    'posts': 725,
#    'comments': 3173,
#    'degree': 5.04,
#    'betweenness': 0.05,
#    'closeness': 62.57,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'scholtes-d',
#    'username': 'scholtes-d',
#    'displayname': 'scholtes-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 63.09,
#    'posts': 647,
#    'comments': 3562,
#    'degree': 11.08,
#    'betweenness': 1.83,
#    'closeness': 66.19,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'schwieger-j',
#    'username': 'schwieger-j',
#    'displayname': 'schwieger-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 45.34,
#    'posts': 738,
#    'comments': 3367,
#    'degree': 18.13,
#    'betweenness': 0.41,
#    'closeness': 70.51,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'hayslett-r',
#    'username': 'hayslett-r',
#    'displayname': 'hayslett-r',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 44.88,
#    'posts': 2554,
#    'comments': 11591,
#    'degree': 21.15,
#    'betweenness': 1.35,
#    'closeness': 71.81,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'bass-e',
#    'username': 'bass-e',
#    'displayname': 'bass-e',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 22.58,
#    'posts': 7823,
#    'comments': 26237,
#    'degree': 20.14,
#    'betweenness': 0.6,
#    'closeness': 69.75,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'wolfe-j',
#    'username': 'wolfe-j',
#    'displayname': 'wolfe-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 51.94,
#    'posts': 1587,
#    'comments': 7797,
#    'degree': 15.11,
#    'betweenness': 0.07,
#    'closeness': 66.19,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'panus-s',
#    'username': 'panus-s',
#    'displayname': 'panus-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 46.51,
#    'posts': 437,
#    'comments': 2021,
#    'degree': 16.12,
#    'betweenness': 0.66,
#    'closeness': 64.65,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'salisbury-h',
#    'username': 'salisbury-h',
#    'displayname': 'salisbury-h',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 57.76,
#    'posts': 1632,
#    'comments': 8523,
#    'degree': 8.06,
#    'betweenness': 0.07,
#    'closeness': 49.77,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'mcconnell-m',
#    'username': 'mcconnell-m',
#    'displayname': 'mcconnell-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 34.39,
#    'posts': 4542,
#    'comments': 18081,
#    'degree': 32.23,
#    'betweenness': 2.54,
#    'closeness': 75.14,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'allen-p',
#    'username': 'allen-p',
#    'displayname': 'allen-p',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 22.89,
#    'posts': 3034,
#    'comments': 10225,
#    'degree': 40.29,
#    'betweenness': 2.19,
#    'closeness': 78.79,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'merriss-s',
#    'username': 'merriss-s',
#    'displayname': 'merriss-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 83.39,
#    'posts': 1627,
#    'comments': 10712,
#    'degree': 1.01,
#    'betweenness': 0.0,
#    'closeness': 36.86,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'donoho-l',
#    'username': 'donoho-l',
#    'displayname': 'donoho-l',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 53.81,
#    'posts': 1045,
#    'comments': 5238,
#    'degree': 17.12,
#    'betweenness': 0.08,
#    'closeness': 59.33,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'zufferli-j',
#    'username': 'zufferli-j',
#    'displayname': 'zufferli-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 40.19,
#    'posts': 557,
#    'comments': 2389,
#    'degree': 12.09,
#    'betweenness': 0.14,
#    'closeness': 66.87,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'farmer-d',
#    'username': 'farmer-d',
#    'displayname': 'farmer-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 50.68,
#    'posts': 13032,
#    'comments': 63159,
#    'degree': 9.06,
#    'betweenness': 0.15,
#    'closeness': 65.97,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'ruscitti-k',
#    'username': 'ruscitti-k',
#    'displayname': 'ruscitti-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 47.71,
#    'posts': 1643,
#    'comments': 7703,
#    'degree': 13.09,
#    'betweenness': 0.17,
#    'closeness': 65.52,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'smith-m',
#    'username': 'smith-m',
#    'displayname': 'smith-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 23.42,
#    'posts': 1642,
#    'comments': 5580,
#    'degree': 13.09,
#    'betweenness': 0.1,
#    'closeness': 65.3,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'gang-l',
#    'username': 'gang-l',
#    'displayname': 'gang-l',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 40.97,
#    'posts': 590,
#    'comments': 2555,
#    'degree': 7.05,
#    'betweenness': 0.05,
#    'closeness': 47.81,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'haedicke-m',
#    'username': 'haedicke-m',
#    'displayname': 'haedicke-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 56.81,
#    'posts': 5246,
#    'comments': 27132,
#    'degree': 31.22,
#    'betweenness': 1.55,
#    'closeness': 73.99,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'tycholiz-b',
#    'username': 'tycholiz-b',
#    'displayname': 'tycholiz-b',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 36.06,
#    'posts': 1219,
#    'comments': 4961,
#    'degree': 33.24,
#    'betweenness': 1.56,
#    'closeness': 76.31,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'kaminski-v',
#    'username': 'kaminski-v',
#    'displayname': 'kaminski-v',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 41.3,
#    'posts': 28465,
#    'comments': 123762,
#    'degree': 29.21,
#    'betweenness': 0.93,
#    'closeness': 74.56,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'derrick-j',
#    'username': 'derrick-j',
#    'displayname': 'derrick-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 53.38,
#    'posts': 1766,
#    'comments': 8812,
#    'degree': 13.09,
#    'betweenness': 0.09,
#    'closeness': 70.51,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'meyers-a',
#    'username': 'meyers-a',
#    'displayname': 'meyers-a',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 58.01,
#    'posts': 1099,
#    'comments': 5754,
#    'degree': 6.04,
#    'betweenness': 0.06,
#    'closeness': 48.77,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'reitmeyer-j',
#    'username': 'reitmeyer-j',
#    'displayname': 'reitmeyer-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 43.9,
#    'posts': 498,
#    'comments': 2234,
#    'degree': 21.15,
#    'betweenness': 0.38,
#    'closeness': 70.25,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'quigley-d',
#    'username': 'quigley-d',
#    'displayname': 'quigley-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 35.09,
#    'posts': 1568,
#    'comments': 6300,
#    'degree': 19.14,
#    'betweenness': 0.53,
#    'closeness': 71.02,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'ward-k',
#    'username': 'ward-k',
#    'displayname': 'ward-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 29.19,
#    'posts': 2611,
#    'comments': 9673,
#    'degree': 20.14,
#    'betweenness': 2.83,
#    'closeness': 68.52,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'symes-k',
#    'username': 'symes-k',
#    'displayname': 'symes-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 28.53,
#    'posts': 10827,
#    'comments': 39730,
#    'degree': 18.13,
#    'betweenness': 2.05,
#    'closeness': 57.57,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'hain-m',
#    'username': 'hain-m',
#    'displayname': 'hain-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 70.77,
#    'posts': 3820,
#    'comments': 22589,
#    'degree': 28.2,
#    'betweenness': 3.16,
#    'closeness': 74.85,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'ermis-f',
#    'username': 'ermis-f',
#    'displayname': 'ermis-f',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 75.05,
#    'posts': 1230,
#    'comments': 7553,
#    'degree': 15.11,
#    'betweenness': 0.08,
#    'closeness': 65.97,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'semperger-c',
#    'username': 'semperger-c',
#    'displayname': 'semperger-c',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 73.58,
#    'posts': 721,
#    'comments': 4371,
#    'degree': 14.1,
#    'betweenness': 0.54,
#    'closeness': 55.76,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'pimenov-v',
#    'username': 'pimenov-v',
#    'displayname': 'pimenov-v',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 56.57,
#    'posts': 642,
#    'comments': 3312,
#    'degree': 12.09,
#    'betweenness': 0.06,
#    'closeness': 65.74,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'buy-r',
#    'username': 'buy-r',
#    'displayname': 'buy-r',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 48.79,
#    'posts': 2429,
#    'comments': 11528,
#    'degree': 18.13,
#    'betweenness': 0.23,
#    'closeness': 71.81,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'linder-e',
#    'username': 'linder-e',
#    'displayname': 'linder-e',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 89.85,
#    'posts': 2805,
#    'comments': 19430,
#    'degree': 5.04,
#    'betweenness': 0.01,
#    'closeness': 48.65,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'phanis-s',
#    'username': 'phanis-s',
#    'displayname': 'phanis-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 55.73,
#    'posts': 35,
#    'comments': 179,
#    'degree': 0.0,
#    'betweenness': 0.0,
#    'closeness': 0.0,
#    'networktype': 'Soloists',
#    'category': 'Soloists'},
#   {'name': 'blair-l',
#    'username': 'blair-l',
#    'displayname': 'blair-l',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 57.52,
#    'posts': 3415,
#    'comments': 17791,
#    'degree': 16.12,
#    'betweenness': 0.05,
#    'closeness': 57.4,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'scott-s',
#    'username': 'scott-s',
#    'displayname': 'scott-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 31.43,
#    'posts': 8022,
#    'comments': 30674,
#    'degree': 39.28,
#    'betweenness': 6.1,
#    'closeness': 74.85,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'arnold-j',
#    'username': 'arnold-j',
#    'displayname': 'arnold-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 23.73,
#    'posts': 4898,
#    'comments': 16726,
#    'degree': 34.24,
#    'betweenness': 1.07,
#    'closeness': 74.85,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'watson-k',
#    'username': 'watson-k',
#    'displayname': 'watson-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 57.86,
#    'posts': 2950,
#    'comments': 15422,
#    'degree': 18.13,
#    'betweenness': 0.14,
#    'closeness': 57.24,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'love-p',
#    'username': 'love-p',
#    'displayname': 'love-p',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 34.29,
#    'posts': 5002,
#    'comments': 19886,
#    'degree': 16.12,
#    'betweenness': 0.32,
#    'closeness': 64.01,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'heard-m',
#    'username': 'heard-m',
#    'displayname': 'heard-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 45.85,
#    'posts': 1623,
#    'comments': 7449,
#    'degree': 13.09,
#    'betweenness': 0.08,
#    'closeness': 60.81,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'davis-d',
#    'username': 'davis-d',
#    'displayname': 'davis-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 36.19,
#    'posts': 2249,
#    'comments': 9168,
#    'degree': 17.12,
#    'betweenness': 0.44,
#    'closeness': 72.07,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'beck-s',
#    'username': 'beck-s',
#    'displayname': 'beck-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 42.77,
#    'posts': 11830,
#    'comments': 52357,
#    'degree': 67.48,
#    'betweenness': 14.17,
#    'closeness': 90.51,
#    'networktype': 'Brokers',
#    'category': 'Brokers',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'lay-k',
#    'username': 'lay-k',
#    'displayname': 'lay-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 66.99,
#    'posts': 5937,
#    'comments': 33916,
#    'degree': 44.32,
#    'betweenness': 6.29,
#    'closeness': 80.08,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'gay-r',
#    'username': 'gay-r',
#    'displayname': 'gay-r',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 34.47,
#    'posts': 1415,
#    'comments': 5639,
#    'degree': 17.12,
#    'betweenness': 0.35,
#    'closeness': 67.34,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'rapp-b',
#    'username': 'rapp-b',
#    'displayname': 'rapp-b',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 60.53,
#    'posts': 563,
#    'comments': 3023,
#    'degree': 13.09,
#    'betweenness': 0.07,
#    'closeness': 55.28,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'lokay-m',
#    'username': 'lokay-m',
#    'displayname': 'lokay-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 48.07,
#    'posts': 5568,
#    'comments': 26211,
#    'degree': 17.12,
#    'betweenness': 0.08,
#    'closeness': 59.33,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000006',
#    'community_size': 16},
#   {'name': 'dorland-c',
#    'username': 'dorland-c',
#    'displayname': 'dorland-c',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 15.8,
#    'posts': 2127,
#    'comments': 6367,
#    'degree': 23.17,
#    'betweenness': 0.96,
#    'closeness': 69.75,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'solberg-g',
#    'username': 'solberg-g',
#    'displayname': 'solberg-g',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 55.06,
#    'posts': 1081,
#    'comments': 5490,
#    'degree': 11.08,
#    'betweenness': 0.19,
#    'closeness': 51.48,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'mann-k',
#    'username': 'mann-k',
#    'displayname': 'mann-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 40.12,
#    'posts': 23381,
#    'comments': 100188,
#    'degree': 18.13,
#    'betweenness': 0.32,
#    'closeness': 64.87,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'giron-d',
#    'username': 'giron-d',
#    'displayname': 'giron-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 26.2,
#    'posts': 4220,
#    'comments': 14964,
#    'degree': 18.13,
#    'betweenness': 0.34,
#    'closeness': 68.52,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'weldon-c',
#    'username': 'weldon-c',
#    'displayname': 'weldon-c',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 28.39,
#    'posts': 1566,
#    'comments': 5735,
#    'degree': 9.06,
#    'betweenness': 0.14,
#    'closeness': 62.57,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'donohoe-t',
#    'username': 'donohoe-t',
#    'displayname': 'donohoe-t',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 66.91,
#    'posts': 1015,
#    'comments': 5794,
#    'degree': 9.06,
#    'betweenness': 0.08,
#    'closeness': 65.97,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'perlingiere-d',
#    'username': 'perlingiere-d',
#    'displayname': 'perlingiere-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 17.08,
#    'posts': 4778,
#    'comments': 14628,
#    'degree': 20.14,
#    'betweenness': 0.58,
#    'closeness': 64.87,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'taylor-m',
#    'username': 'taylor-m',
#    'displayname': 'taylor-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 42.23,
#    'posts': 13875,
#    'comments': 61012,
#    'degree': 29.21,
#    'betweenness': 1.69,
#    'closeness': 73.43,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'steffes-j',
#    'username': 'steffes-j',
#    'displayname': 'steffes-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 70.47,
#    'posts': 3331,
#    'comments': 19644,
#    'degree': 26.19,
#    'betweenness': 0.51,
#    'closeness': 73.16,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'delainey-d',
#    'username': 'delainey-d',
#    'displayname': 'delainey-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 25.84,
#    'posts': 3566,
#    'comments': 12577,
#    'degree': 38.27,
#    'betweenness': 2.27,
#    'closeness': 78.47,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'causholli-m',
#    'username': 'causholli-m',
#    'displayname': 'causholli-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 47.05,
#    'posts': 943,
#    'comments': 4388,
#    'degree': 8.06,
#    'betweenness': 0.7,
#    'closeness': 56.41,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'lenhart-m',
#    'username': 'lenhart-m',
#    'displayname': 'lenhart-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 9.83,
#    'posts': 5920,
#    'comments': 15845,
#    'degree': 24.17,
#    'betweenness': 0.6,
#    'closeness': 70.76,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'holst-k',
#    'username': 'holst-k',
#    'displayname': 'holst-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 61.02,
#    'posts': 463,
#    'comments': 2498,
#    'degree': 22.16,
#    'betweenness': 0.5,
#    'closeness': 71.54,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'zipper-a',
#    'username': 'zipper-a',
#    'displayname': 'zipper-a',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 45.22,
#    'posts': 1563,
#    'comments': 7121,
#    'degree': 30.22,
#    'betweenness': 0.85,
#    'closeness': 74.56,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'lewis-a',
#    'username': 'lewis-a',
#    'displayname': 'lewis-a',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 71.56,
#    'posts': 2191,
#    'comments': 13048,
#    'degree': 7.05,
#    'betweenness': 0.03,
#    'closeness': 63.39,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'cuilla-m',
#    'username': 'cuilla-m',
#    'displayname': 'cuilla-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 61.0,
#    'posts': 1029,
#    'comments': 5551,
#    'degree': 22.16,
#    'betweenness': 0.48,
#    'closeness': 69.25,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'gilbertsmith-d',
#    'username': 'gilbertsmith-d',
#    'displayname': 'gilbertsmith-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 47.75,
#    'posts': 578,
#    'comments': 2711,
#    'degree': 0.0,
#    'betweenness': 0.0,
#    'closeness': 0.0,
#    'networktype': 'Soloists',
#    'category': 'Soloists'},
#   {'name': 'sanchez-m',
#    'username': 'sanchez-m',
#    'displayname': 'sanchez-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 33.28,
#    'posts': 256,
#    'comments': 1004,
#    'degree': 30.22,
#    'betweenness': 1.1,
#    'closeness': 73.99,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'whitt-m',
#    'username': 'whitt-m',
#    'displayname': 'whitt-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 47.44,
#    'posts': 807,
#    'comments': 3772,
#    'degree': 17.12,
#    'betweenness': 0.61,
#    'closeness': 68.52,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'ring-r',
#    'username': 'ring-r',
#    'displayname': 'ring-r',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 61.15,
#    'posts': 994,
#    'comments': 5370,
#    'degree': 3.02,
#    'betweenness': 0.01,
#    'closeness': 54.21,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'fischer-m',
#    'username': 'fischer-m',
#    'displayname': 'fischer-m',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 44.05,
#    'posts': 1498,
#    'comments': 6732,
#    'degree': 0.0,
#    'betweenness': 0.0,
#    'closeness': 0.0,
#    'networktype': 'Soloists',
#    'category': 'Soloists'},
#   {'name': 'parks-j',
#    'username': 'parks-j',
#    'displayname': 'parks-j',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 36.74,
#    'posts': 2284,
#    'comments': 9377,
#    'degree': 11.08,
#    'betweenness': 0.21,
#    'closeness': 66.87,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'neal-s',
#    'username': 'neal-s',
#    'displayname': 'neal-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 41.28,
#    'posts': 3268,
#    'comments': 14205,
#    'degree': 41.29,
#    'betweenness': 2.4,
#    'closeness': 77.53,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'shackleton-s',
#    'username': 'shackleton-s',
#    'displayname': 'shackleton-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 48.1,
#    'posts': 18687,
#    'comments': 87995,
#    'degree': 24.17,
#    'betweenness': 0.83,
#    'closeness': 68.04,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000003',
#    'community_size': 17},
#   {'name': 'kuykendall-t',
#    'username': 'kuykendall-t',
#    'displayname': 'kuykendall-t',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 24.43,
#    'posts': 1120,
#    'comments': 3866,
#    'degree': 25.18,
#    'betweenness': 0.77,
#    'closeness': 71.54,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'thomas-p',
#    'username': 'thomas-p',
#    'displayname': 'thomas-p',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 82.27,
#    'posts': 1293,
#    'comments': 8436,
#    'degree': 5.04,
#    'betweenness': 0.02,
#    'closeness': 57.24,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'white-s',
#    'username': 'white-s',
#    'displayname': 'white-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 61.31,
#    'posts': 3272,
#    'comments': 17705,
#    'degree': 15.11,
#    'betweenness': 0.83,
#    'closeness': 69.5,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'brawner-s',
#    'username': 'brawner-s',
#    'displayname': 'brawner-s',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 39.94,
#    'posts': 1026,
#    'comments': 4387,
#    'degree': 10.07,
#    'betweenness': 0.04,
#    'closeness': 64.44,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'sturm-f',
#    'username': 'sturm-f',
#    'displayname': 'sturm-f',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 39.77,
#    'posts': 1169,
#    'comments': 4988,
#    'degree': 25.18,
#    'betweenness': 0.62,
#    'closeness': 72.88,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'presto-k',
#    'username': 'presto-k',
#    'displayname': 'presto-k',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 39.5,
#    'posts': 2204,
#    'comments': 9372,
#    'degree': 27.19,
#    'betweenness': 1.57,
#    'closeness': 76.61,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000002',
#    'community_size': 21},
#   {'name': 'richey-c',
#    'username': 'richey-c',
#    'displayname': 'richey-c',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 22.3,
#    'posts': 582,
#    'comments': 1943,
#    'degree': 11.08,
#    'betweenness': 0.11,
#    'closeness': 63.8,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000000',
#    'community_size': 25},
#   {'name': 'badeer-r',
#    'username': 'badeer-r',
#    'displayname': 'badeer-r',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 78.69,
#    'posts': 877,
#    'comments': 5555,
#    'degree': 20.14,
#    'betweenness': 1.69,
#    'closeness': 71.28,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000005',
#    'community_size': 18},
#   {'name': 'williams-w3',
#    'username': 'williams-w3',
#    'displayname': 'williams-w3',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 58.0,
#    'posts': 3440,
#    'comments': 18009,
#    'degree': 0.0,
#    'betweenness': 0.0,
#    'closeness': 0.0,
#    'networktype': 'Soloists',
#    'category': 'Soloists'},
#   {'name': 'ring-a',
#    'username': 'ring-a',
#    'displayname': 'ring-a',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 41.44,
#    'posts': 706,
#    'comments': 3075,
#    'degree': 16.12,
#    'betweenness': 0.71,
#    'closeness': 67.34,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000001',
#    'community_size': 25},
#   {'name': 'campbell-l',
#    'username': 'campbell-l',
#    'displayname': 'campbell-l',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 61.43,
#    'posts': 6490,
#    'comments': 35157,
#    'degree': 11.08,
#    'betweenness': 0.48,
#    'closeness': 60.62,
#    'networktype': 'Soloists',
#    'category': 'Soloists',
#    'community': '000004',
#    'community_size': 18},
#   {'name': 'fossum-d',
#    'username': 'fossum-d',
#    'displayname': 'fossum-d',
#    'boardarea': 'None',
#    'functionalarea': 'None',
#    'costcenter': 'None',
#    'officelocation': 'None',
#    'localinfo': 'None',
#    'region': 'None',
#    'city': 'None',
#    'profile': 'None',
#    'email': 'None',
#    'mobile': 'None',
#    'value': 39.77,
#    'posts': 4796,
#    'comments': 20464,
#    'degree': 24.17,
#    'betweenness': 1.38,
#    'closeness': 65.3,
#    'networktype': 'Soloists',
# ...
#   {'source': 'delainey-d', 'target': 'kean-s', 'weight': 34},
#   {'source': 'delainey-d', 'target': 'skilling-j', 'weight': 37},
#   {'source': 'delainey-d', 'target': 'tycholiz-b', 'weight': 39},
#   {'source': 'delainey-d', 'target': 'buy-r', 'weight': 54},
#   {'source': 'delainey-d', 'target': 'shapiro-r', 'weight': 46},
#   {'source': 'delainey-d', 'target': 'whalley-g', 'weight': 56},
#   {'source': 'delainey-d', 'target': 'mcconnell-m', 'weight': 11},
#   {'source': 'delainey-d', 'target': 'sager-e', 'weight': 4},
#   {'source': 'delainey-d', 'target': 'sanders-r', 'weight': 6},
#   {'source': 'delainey-d', 'target': 'rogers-b', 'weight': 8},
#   {'source': 'delainey-d', 'target': 'kitchen-l', 'weight': 21},
#   {'source': 'delainey-d', 'target': 'brawner-s', 'weight': 3},
#   {'source': 'delainey-d', 'target': 'derrick-j', 'weight': 3},
#   {'source': 'delainey-d', 'target': 'schwieger-j', 'weight': 8},
#   {'source': 'steffes-j', 'target': 'presto-k', 'weight': 28},
#   {'source': 'tycholiz-b', 'target': 'delainey-d', 'weight': 4},
#   {'source': 'derrick-j', 'target': 'haedicke-m', 'weight': 13},
#   {'source': 'derrick-j', 'target': 'sanders-r', 'weight': 15},
#   {'source': 'haedicke-m', 'target': 'derrick-j', 'weight': 17},
#   {'source': 'horton-s', 'target': 'fossum-d', 'weight': 12},
#   {'source': 'cash-m', 'target': 'derrick-j', 'weight': 1},
#   {'source': 'haedicke-m', 'target': 'shapiro-r', 'weight': 7},
#   {'source': 'haedicke-m', 'target': 'whalley-g', 'weight': 12},
#   {'source': 'haedicke-m', 'target': 'kitchen-l', 'weight': 27},
#   {'source': 'haedicke-m', 'target': 'buy-r', 'weight': 9},
#   {'source': 'haedicke-m', 'target': 'steffes-j', 'weight': 2},
#   {'source': 'haedicke-m', 'target': 'sanders-r', 'weight': 53},
#   {'source': 'sanders-r', 'target': 'derrick-j', 'weight': 33},
#   {'source': 'kean-s', 'target': 'derrick-j', 'weight': 34},
#   {'source': 'derrick-j', 'target': 'kean-s', 'weight': 1},
#   {'source': 'derrick-j', 'target': 'cash-m', 'weight': 6},
#   {'source': 'derrick-j', 'target': 'skilling-j', 'weight': 5},
#   {'source': 'derrick-j', 'target': 'lay-k', 'weight': 7},
#   {'source': 'derrick-j', 'target': 'mcconnell-m', 'weight': 1},
#   {'source': 'derrick-j', 'target': 'fossum-d', 'weight': 12},
#   {'source': 'derrick-j', 'target': 'whalley-g', 'weight': 3},
#   {'source': 'dickson-s', 'target': 'hodge-j', 'weight': 12},
#   {'source': 'dickson-s', 'target': 'shackleton-s', 'weight': 12},
#   {'source': 'dickson-s', 'target': 'williams-j', 'weight': 4},
#   {'source': 'dickson-s', 'target': 'perlingiere-d', 'weight': 19},
#   {'source': 'dickson-s', 'target': 'hyvl-d', 'weight': 35},
#   {'source': 'dickson-s', 'target': 'pereira-s', 'weight': 2},
#   {'source': 'dickson-s', 'target': 'mckay-b', 'weight': 2},
#   {'source': 'mcconnell-m', 'target': 'donoho-l', 'weight': 17},
#   {'source': 'mcconnell-m', 'target': 'lokay-m', 'weight': 26},
#   {'source': 'lokay-m', 'target': 'harris-s', 'weight': 100},
#   {'source': 'lokay-m', 'target': 'watson-k', 'weight': 100},
#   {'source': 'lokay-m', 'target': 'donoho-l', 'weight': 100},
#   {'source': 'lokay-m', 'target': 'mcconnell-m', 'weight': 100},
#   {'source': 'watson-k', 'target': 'donoho-l', 'weight': 100},
#   {'source': 'watson-k', 'target': 'harris-s', 'weight': 100},
#   {'source': 'watson-k', 'target': 'rapp-b', 'weight': 22},
#   {'source': 'rapp-b', 'target': 'mcconnell-m', 'weight': 34},
#   {'source': 'rapp-b', 'target': 'lokay-m', 'weight': 23},
#   {'source': 'hayslett-r', 'target': 'donoho-l', 'weight': 13},
#   {'source': 'hayslett-r', 'target': 'mccarty-d', 'weight': 46},
#   {'source': 'hayslett-r', 'target': 'harris-s', 'weight': 27},
#   {'source': 'hayslett-r', 'target': 'lokay-m', 'weight': 11},
#   {'source': 'lokay-m', 'target': 'hayslett-r', 'weight': 7},
#   {'source': 'geaccone-t', 'target': 'donoho-l', 'weight': 19},
#   {'source': 'hyatt-k', 'target': 'hayslett-r', 'weight': 5},
#   {'source': 'hyatt-k', 'target': 'donoho-l', 'weight': 35},
#   {'source': 'hyatt-k', 'target': 'geaccone-t', 'weight': 6},
#   {'source': 'hyatt-k', 'target': 'harris-s', 'weight': 17},
#   {'source': 'harris-s', 'target': 'donoho-l', 'weight': 21},
#   {'source': 'horton-s', 'target': 'mcconnell-m', 'weight': 11},
#   {'source': 'horton-s', 'target': 'donoho-l', 'weight': 8},
#   {'source': 'horton-s', 'target': 'lokay-m', 'weight': 3},
#   {'source': 'horton-s', 'target': 'hyatt-k', 'weight': 4},
#   {'source': 'horton-s', 'target': 'blair-l', 'weight': 2},
#   {'source': 'mcconnell-m', 'target': 'harris-s', 'weight': 15},
#   {'source': 'mcconnell-m', 'target': 'watson-k', 'weight': 66},
#   {'source': 'lokey-t', 'target': 'donoho-l', 'weight': 8},
#   {'source': 'lokey-t', 'target': 'geaccone-t', 'weight': 8},
#   {'source': 'harris-s', 'target': 'hayslett-r', 'weight': 2},
#   {'source': 'geaccone-t', 'target': 'harris-s', 'weight': 69},
#   {'source': 'lokey-t', 'target': 'harris-s', 'weight': 11},
#   {'source': 'lokey-t', 'target': 'watson-k', 'weight': 14},
#   {'source': 'lokey-t', 'target': 'rapp-b', 'weight': 14},
#   {'source': 'schoolcraft-d', 'target': 'donoho-l', 'weight': 10},
#   {'source': 'mcconnell-m', 'target': 'rapp-b', 'weight': 16},
#   {'source': 'mcconnell-m', 'target': 'hyatt-k', 'weight': 5},
#   {'source': 'hyatt-k', 'target': 'mcconnell-m', 'weight': 12},
#   {'source': 'hyatt-k', 'target': 'lokay-m', 'weight': 71},
#   {'source': 'harris-s', 'target': 'watson-k', 'weight': 46},
#   {'source': 'harris-s', 'target': 'lokey-t', 'weight': 15},
#   {'source': 'harris-s', 'target': 'mcconnell-m', 'weight': 13},
#   {'source': 'harris-s', 'target': 'lokay-m', 'weight': 29},
#   {'source': 'hyatt-k', 'target': 'schoolcraft-d', 'weight': 11},
#   {'source': 'lokey-t', 'target': 'schoolcraft-d', 'weight': 3},
#   {'source': 'donoho-l', 'target': 'geaccone-t', 'weight': 29},
#   {'source': 'donoho-l', 'target': 'hayslett-r', 'weight': 6},
#   {'source': 'donoho-l', 'target': 'mcconnell-m', 'weight': 13},
#   {'source': 'donoho-l', 'target': 'hyatt-k', 'weight': 37},
#   {'source': 'donoho-l', 'target': 'fossum-d', 'weight': 18},
#   {'source': 'donoho-l', 'target': 'mccarty-d', 'weight': 3},
#   {'source': 'donohoe-t', 'target': 'shively-h', 'weight': 4},
#   {'source': 'mims-thurston-p', 'target': 'donohoe-t', 'weight': 7},
#   {'source': 'whalley-g', 'target': 'donohoe-t', 'weight': 2},
#   {'source': 'germany-c', 'target': 'donohoe-t', 'weight': 10},
#   {'source': 'donohoe-t', 'target': 'lay-k', 'weight': 2},
#   {'source': 'donohoe-t', 'target': 'whalley-g', 'weight': 3},
#   {'source': 'donohoe-t', 'target': 'ruscitti-k', 'weight': 7},
#   {'source': 'dorland-c', 'target': 'sanchez-m', 'weight': 2},
#   {'source': 'dorland-c', 'target': 'carson-m', 'weight': 7},
#   {'source': 'dorland-c', 'target': 'tycholiz-b', 'weight': 13},
#   {'source': 'dorland-c', 'target': 'lavorato-j', 'weight': 23},
#   {'source': 'dorland-c', 'target': 'thomas-p', 'weight': 11},
#   {'source': 'dorland-c', 'target': 'mckay-j', 'weight': 29},
#   {'source': 'dorland-c', 'target': 'presto-k', 'weight': 5},
#   {'source': 'mckay-j', 'target': 'dorland-c', 'weight': 4},
#   {'source': 'zufferli-j', 'target': 'dorland-c', 'weight': 9},
#   {'source': 'zufferli-j', 'target': 'richey-c', 'weight': 22},
#   {'source': 'dorland-c', 'target': 'grigsby-m', 'weight': 12},
#   {'source': 'dorland-c', 'target': 'zufferli-j', 'weight': 15},
#   {'source': 'dorland-c', 'target': 'richey-c', 'weight': 8},
#   {'source': 'dorland-c', 'target': 'lenhart-m', 'weight': 3},
#   {'source': 'dorland-c', 'target': 'ermis-f', 'weight': 1},
#   {'source': 'dorland-c', 'target': 'king-j', 'weight': 1},
#   {'source': 'dorland-c', 'target': 'cuilla-m', 'weight': 2},
#   {'source': 'dorland-c', 'target': 'storey-g', 'weight': 7},
#   {'source': 'ermis-f', 'target': 'grigsby-m', 'weight': 7},
#   {'source': 'ermis-f', 'target': 'reitmeyer-j', 'weight': 10},
#   {'source': 'ermis-f', 'target': 'lenhart-m', 'weight': 4},
#   {'source': 'grigsby-m', 'target': 'tholt-j', 'weight': 73},
#   {'source': 'grigsby-m', 'target': 'allen-p', 'weight': 96},
#   {'source': 'whitt-m', 'target': 'grigsby-m', 'weight': 11},
#   {'source': 'whitt-m', 'target': 'south-s', 'weight': 5},
#   {'source': 'whitt-m', 'target': 'ermis-f', 'weight': 5},
#   {'source': 'whitt-m', 'target': 'tycholiz-b', 'weight': 100},
#   {'source': 'kuykendall-t', 'target': 'holst-k', 'weight': 10},
#   {'source': 'kuykendall-t', 'target': 'sanchez-m', 'weight': 9},
#   {'source': 'kuykendall-t', 'target': 'allen-p', 'weight': 6},
#   {'source': 'kuykendall-t', 'target': 'tholt-j', 'weight': 9},
#   {'source': 'kuykendall-t', 'target': 'scott-s', 'weight': 10},
#   {'source': 'kuykendall-t', 'target': 'gay-r', 'weight': 18},
#   {'source': 'kuykendall-t', 'target': 'grigsby-m', 'weight': 22},
#   {'source': 'kuykendall-t', 'target': 'reitmeyer-j', 'weight': 18},
#   {'source': 'kuykendall-t', 'target': 'ermis-f', 'weight': 6},
#   {'source': 'kuykendall-t', 'target': 'lenhart-m', 'weight': 24},
#   {'source': 'reitmeyer-j', 'target': 'holst-k', 'weight': 11},
#   {'source': 'reitmeyer-j', 'target': 'allen-p', 'weight': 6},
#   {'source': 'reitmeyer-j', 'target': 'kuykendall-t', 'weight': 9},
#   {'source': 'reitmeyer-j', 'target': 'grigsby-m', 'weight': 17},
#   {'source': 'reitmeyer-j', 'target': 'ermis-f', 'weight': 18},
#   {'source': 'reitmeyer-j', 'target': 'lenhart-m', 'weight': 9},
#   {'source': 'reitmeyer-j', 'target': 'south-s', 'weight': 3},
#   {'source': 'wolfe-j', 'target': 'ermis-f', 'weight': 5},
#   {'source': 'ermis-f', 'target': 'south-s', 'weight': 1},
#   {'source': 'lenhart-m', 'target': 'ermis-f', 'weight': 27},
#   {'source': 'farmer-d', 'target': 'martin-t', 'weight': 12},
#   {'source': 'farmer-d', 'target': 'griffith-j', 'weight': 8},
#   {'source': 'farmer-d', 'target': 'hyvl-d', 'weight': 4},
#   {'source': 'farmer-d', 'target': 'bass-e', 'weight': 4},
#   {'source': 'farmer-d', 'target': 'gay-r', 'weight': 4},
#   {'source': 'farmer-d', 'target': 'beck-s', 'weight': 2},
#   {'source': 'hain-m', 'target': 'farmer-d', 'weight': 3},
#   {'source': 'kuykendall-t', 'target': 'farmer-d', 'weight': 3},
#   {'source': 'griffith-j', 'target': 'farmer-d', 'weight': 4},
#   {'source': 'forney-j', 'target': 'ward-k', 'weight': 1},
#   {'source': 'forney-j', 'target': 'sager-e', 'weight': 3},
#   {'source': 'forney-j', 'target': 'badeer-r', 'weight': 2},
#   {'source': 'forney-j', 'target': 'carson-m', 'weight': 1},
#   {'source': 'fossum-d', 'target': 'hyatt-k', 'weight': 100},
#   {'source': 'fossum-d', 'target': 'scott-s', 'weight': 100},
#   {'source': 'fossum-d', 'target': 'donoho-l', 'weight': 16},
#   {'source': 'fossum-d', 'target': 'schoolcraft-d', 'weight': 6},
#   {'source': 'fossum-d', 'target': 'lokey-t', 'weight': 7},
#   {'source': 'fossum-d', 'target': 'dasovich-j', 'weight': 3},
#   {'source': 'fossum-d', 'target': 'whitt-m', 'weight': 3},
#   {'source': 'corman-s', 'target': 'scott-s', 'weight': 85},
#   {'source': 'harris-s', 'target': 'fossum-d', 'weight': 21},
#   {'source': 'corman-s', 'target': 'hain-m', 'weight': 32},
#   {'source': 'scott-s', 'target': 'fossum-d', 'weight': 81},
#   {'source': 'donoho-l', 'target': 'scott-s', 'weight': 15},
#   {'source': 'meyers-a', 'target': 'gang-l', 'weight': 1},
#   {'source': 'platter-p', 'target': 'gang-l', 'weight': 1},
#   {'source': 'gay-r', 'target': 'south-s', 'weight': 8},
#   {'source': 'gay-r', 'target': 'tholt-j', 'weight': 8},
#   {'source': 'gay-r', 'target': 'reitmeyer-j', 'weight': 12},
#   {'source': 'gay-r', 'target': 'ermis-f', 'weight': 4},
#   {'source': 'gay-r', 'target': 'kuykendall-t', 'weight': 27},
#   {'source': 'gay-r', 'target': 'lenhart-m', 'weight': 4},
#   {'source': 'gay-r', 'target': 'allen-p', 'weight': 17},
#   {'source': 'gay-r', 'target': 'grigsby-m', 'weight': 4},
#   {'source': 'gay-r', 'target': 'germany-c', 'weight': 4},
#   {'source': 'gay-r', 'target': 'richey-c', 'weight': 4},
#   {'source': 'gay-r', 'target': 'staab-t', 'weight': 3},
#   {'source': 'grigsby-m', 'target': 'gay-r', 'weight': 38},
#   {'source': 'lenhart-m', 'target': 'gay-r', 'weight': 22},
#   {'source': 'geaccone-t', 'target': 'scott-s', 'weight': 1},
#   {'source': 'geaccone-t', 'target': 'schoolcraft-d', 'weight': 2},
#   {'source': 'geaccone-t', 'target': 'hyatt-k', 'weight': 3},
#   {'source': 'geaccone-t', 'target': 'mccarty-d', 'weight': 10},
#   {'source': 'mcconnell-m', 'target': 'lokey-t', 'weight': 14},
#   {'source': 'mcconnell-m', 'target': 'hayslett-r', 'weight': 12},
#   {'source': 'mcconnell-m', 'target': 'geaccone-t', 'weight': 9},
#   {'source': 'lokay-m', 'target': 'geaccone-t', 'weight': 2},
#   {'source': 'watson-k', 'target': 'geaccone-t', 'weight': 16},
#   {'source': 'geaccone-t', 'target': 'watson-k', 'weight': 22},
#   {'source': 'harris-s', 'target': 'geaccone-t', 'weight': 33},
#   {'source': 'horton-s', 'target': 'geaccone-t', 'weight': 2},
#   {'source': 'hayslett-r', 'target': 'fossum-d', 'weight': 45},
#   {'source': 'geaccone-t', 'target': 'fossum-d', 'weight': 6},
#   {'source': 'geaccone-t', 'target': 'mcconnell-m', 'weight': 3},
#   {'source': 'geaccone-t', 'target': 'lokay-m', 'weight': 6},
#   {'source': 'geaccone-t', 'target': 'horton-s', 'weight': 7},
#   {'source': 'germany-c', 'target': 'cuilla-m', 'weight': 14},
#   {'source': 'germany-c', 'target': 'hendrickson-s', 'weight': 100},
#   {'source': 'germany-c', 'target': 'lewis-a', 'weight': 4},
#   {'source': 'germany-c', 'target': 'townsend-j', 'weight': 100},
#   {'source': 'germany-c', 'target': 'ruscitti-k', 'weight': 83},
#   {'source': 'germany-c', 'target': 'hodge-j', 'weight': 63},
#   {'source': 'germany-c', 'target': 'pereira-s', 'weight': 44},
#   {'source': 'germany-c', 'target': 'ring-a', 'weight': 35},
#   {'source': 'germany-c', 'target': 'neal-s', 'weight': 100},
#   {'source': 'germany-c', 'target': 'shively-h', 'weight': 29},
#   {'source': 'germany-c', 'target': 'gay-r', 'weight': 4},
#   {'source': 'germany-c', 'target': 'keiser-k', 'weight': 16},
#   {'source': 'germany-c', 'target': 'mckay-b', 'weight': 9},
#   {'source': 'germany-c', 'target': 'storey-g', 'weight': 7},
#   {'source': 'townsend-j', 'target': 'germany-c', 'weight': 57},
#   {'source': 'neal-s', 'target': 'germany-c', 'weight': 45},
#   {'source': 'pereira-s', 'target': 'germany-c', 'weight': 6},
#   {'source': 'hodge-j', 'target': 'germany-c', 'weight': 15},
#   {'source': 'hendrickson-s', 'target': 'germany-c', 'weight': 16},
#   {'source': 'germany-c', 'target': 'farmer-d', 'weight': 2},
#   {'source': 'hodge-j', 'target': 'mckay-b', 'weight': 6},
#   {'source': 'hodge-j', 'target': 'neal-s', 'weight': 9},
#   {'source': 'neal-s', 'target': 'pereira-s', 'weight': 30},
#   {'source': 'neal-s', 'target': 'brawner-s', 'weight': 76},
#   {'source': 'neal-s', 'target': 'mckay-b', 'weight': 82},
#   {'source': 'neal-s', 'target': 'hendrickson-s', 'weight': 36},
#   {'source': 'bailey-s', 'target': 'germany-c', 'weight': 2},
#   {'source': 'panus-s', 'target': 'germany-c', 'weight': 4},
#   {'source': 'parks-j', 'target': 'germany-c', 'weight': 9},
#   {'source': 'germany-c', 'target': 'parks-j', 'weight': 42},
#   {'source': 'germany-c', 'target': 'mann-k', 'weight': 43},
#   {'source': 'mann-k', 'target': 'germany-c', 'weight': 10},
#   {'source': 'keiser-k', 'target': 'germany-c', 'weight': 9},
#   {'source': 'keiser-k', 'target': 'pimenov-v', 'weight': 6},
#   {'source': 'keiser-k', 'target': 'neal-s', 'weight': 6},
#   {'source': 'keiser-k', 'target': 'mckay-j', 'weight': 6},
#   {'source': 'keiser-k', 'target': 'ring-a', 'weight': 7},
#   {'source': 'keiser-k', 'target': 'mckay-b', 'weight': 4},
#   {'source': 'keiser-k', 'target': 'townsend-j', 'weight': 6},
#   {'source': 'keiser-k', 'target': 'hodge-j', 'weight': 5},
#   {'source': 'germany-c', 'target': 'shackleton-s', 'weight': 1},
#   {'source': 'hyatt-k', 'target': 'germany-c', 'weight': 1},
#   {'source': 'germany-c', 'target': 'pimenov-v', 'weight': 2},
#   {'source': 'germany-c', 'target': 'mckay-j', 'weight': 2},
#   {'source': 'germany-c', 'target': 'hayslett-r', 'weight': 1},
#   {'source': 'germany-c', 'target': 'hyatt-k', 'weight': 1},
#   {'source': 'presto-k', 'target': 'shapiro-r', 'weight': 1},
#   {'source': 'presto-k', 'target': 'steffes-j', 'weight': 1},
#   ...]}
